# %%
import re
class restaurant:
    
 print("welcome to my resturant")
    
 def name(self):
   s=input("input your user name:")
   while True:
    if re.findall("[A-Za-z]",s):
       print("valid name")
       break
    else: 
       print("Invalid name")
       s=input("Enter valid name:")
       
     
   
   
 def phone_numbers(self):
 
   n=input("Enter your mobile Number:")
   m=re.fullmatch("[6-9][0-9]{9}",n)
   while True:
    if m!=None:  
     print("Mobile number is valid")
     break
    else:    
     print("Mobile number is invalid")
     n=input("Enter valid number:")
     

 def email(self):
   q=input("enter the email:")
   t=re.search("[^a-zA-Z0-9]+[a-zA-Z0-9]",q)
  
   while True:
    if t!=None:
     print("Valid email")
     break
    else:
     print("Invalid email")
     q=input("enter valid email")

 def password(self):  
   p=input("Input your password:")
   e=re.search("[a-zA-Z0-9]*[^a-zA-Z0-9]",p)
   while True:  
 #   if (len(p)<6 or len(p)>12):
    if e!=None:
 
     print("Valid Password")
     print("successfully logined to the application")
     break
    else:
         print("Need strong password")
         p=input("enter strong password:")
 
 def food_list(self):  
     print("list of food items are:\n 1.Tandoori chicken(4 pices)[INR 240]\n 2.vegan burger(1 piece)[INR 320]  \n 3.Truffle Cake (500gm) [INR 900]")
 def place_order(self):
 
  s=int(input("enter the food_id:"))
  while True:
   if s==1:
    print("tandoori chicken")
    break
   if s==2:
    print("vegan burger")
    break
   if s==3:
    print("truffle cake")
    break 
   else:
    print(" food id not vaild")
    s=int(input("enter correct food id"))   
    
# def order_history(self):
  print("view the previous history of order:",s)
  while True:
   if s==1:
    print("tandoori chicken")
    break
   if s==2:
    print("vegan burger")
    break
   if s==3:
    print("truffle cake")
    break 
  
 
        
        

     


z=restaurant()    
z.name()
z.phone_numbers()
z.email()
z.password()
z.food_list()
z.place_order()
# Out:
# welcome to my resturant
# input your user name:Shravan
# valid name
# Enter your mobile Number:9591701069
# Mobile number is valid
# enter the email:Shravanacharya2001@gmail.com
# Valid email
# Input your password:qwey@#1234
# Valid Password
# successfully logined to the application
# list of food items are:
#  1.Tandoori chicken(4 pices)[INR 240]
#  2.vegan burger(1 piece)[INR 320]
#  3.Truffle Cake (500gm) [INR 900]
# enter the food_id:2
# vegan burger
# view the previous history of order: 2
# vegan burger
